# %% [markdown]
# i want to print hello

# %%
print("hello, sir")
# Out:
# hello, sir

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# # What is python ?
#
# Python is high-level, interpreted, object oriented and general purpose programming language that is designed to be easy to read, write and learn.

# %% [markdown]
# ## Variables and Datatypes

# %% [markdown]
# WAP to add two numbers..

# %% [markdown]
# A variable is a name given to a memory location where data is stored, and its value can change during program execution.

# %%
num1 = 12
num2 = 14
res = num1 + num2
print(res)
# Out:
# 26

# %% [markdown]
# - variable name should not start with number
# - there should not be space between name of variable
# - do not start the name with any special characters
# - variable name should have meanings

# %%
employee_name ="Neha"

# %%
print(num1)
# Out:
# 12

# %%
id(num1)
# Out:
# 4378931464

# %%
id(num2)
# Out:
# 4378931528

# %%
id(res)
# Out:
# 4378931912

# %% [markdown]
# ### Data types
#
# numeric(integer,float,complex),
#
# string("",''),
#
# boolean(True,False)

# %%
num = 45
name = "Rohit"
price = 45.89
flag = True
cl = 2+3j

# %%
print(type(num))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(price))
# Out:
# <class 'float'>

# %%
print(type(flag))
# Out:
# <class 'bool'>

# %%
print(type(cl))
# Out:
# <class 'complex'>

# %% [markdown]
# ### print function

# %%
print("hello")
# Out:
# hello

# %%
age = 35
name = "Rahul"
print("His age is :",age," name: ",name)
# Out:
# His age is : 35  name:  Rahul

# %%
print(f"His name is {name} and age is {age}")
# Out:
# His name is Rahul and age is 35

# %%
st = f"His name is {name} and age is {age}"

# %%
print(type(st))
# Out:
# <class 'str'>
